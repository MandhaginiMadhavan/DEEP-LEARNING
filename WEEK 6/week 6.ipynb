# %%
#
# Import Libraries
#
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Your code to read data
df = pd.read_csv("RSCCASN.csv", index_col='DATE', parse_dates=True)
df.head()
# Print first few rows of data
# Out:
#             RSCCASN
# DATE
# 1992-01-01   6938.0
# 1992-02-01   7524.0
# 1992-03-01   8475.0
# 1992-04-01   9401.0
# 1992-05-01   9558.0

# %%
# Set name of column as 'Sales'. Use - df.columns 
df.columns = ['sales']

# %%
# Your code to plot Year vs Sales. Use either matplot library of pandas dataframe.
df.head()
# Out:
#              sales
# DATE
# 1992-01-01  6938.0
# 1992-02-01  7524.0
# 1992-03-01  8475.0
# 1992-04-01  9401.0
# 1992-05-01  9558.0

# %%
df.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
test_size = 18

# %%
#Assign the start of test index in data frame to variable test_index.  Remember, it is equal to the length of dataframe - test size
data_length = len(df)
data_length
# Out:
# 387

# %%
len(df)- 18
# Out:
# 369

# %%
train_size = data_length- test_size
train_size
# Out:
# 369

# %%
test_index =  train_size

# %%
train = df.iloc[:test_index]
test = df.iloc[test_index:]

# %%
print(train.size)
print(test.size)
# Out:
# 369
# 18

# %%
train
# Out:
#               sales
# DATE
# 1992-01-01   6938.0
# 1992-02-01   7524.0
# 1992-03-01   8475.0
# 1992-04-01   9401.0
# 1992-05-01   9558.0
# ...             ...
# 2022-05-01  26156.0
# 2022-06-01  24338.0
# 2022-07-01  24530.0
# 2022-08-01  25651.0
# 2022-09-01  23152.0
#
# [369 rows x 1 columns]

# %%
test
# Out:
#               sales
# DATE
# 2022-10-01  24243.0
# 2022-11-01  28045.0
# 2022-12-01  39263.0
# 2023-01-01  19118.0
# 2023-02-01  20666.0
# 2023-03-01  24510.0
# 2023-04-01  24232.0
# 2023-05-01  26096.0
# 2023-06-01  24364.0
# 2023-07-01  24911.0
# 2023-08-01  26657.0
# 2023-09-01  23332.0
# 2023-10-01  23933.0
# 2023-11-01  28580.0
# 2023-12-01  40684.0
# 2024-01-01  19188.0
# 2024-02-01  21964.0
# 2024-03-01  25293.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
#
# Check if the data has been scaled properly
#
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
print(scaled_train.max())
print(scaled_test.max())
print(scaled_train.min())
print(scaled_test.min())
# Out:
# 1.0
# 1.0553158319645888
# 0.0
# 0.4549427911249687

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
length = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)
# Out:
# WARNING:tensorflow:From C:\Users\mandh\AppData\Local\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X, y = generator[0]

print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.11586537 0.13217895 0.15865371 0.1844325  0.18880321 0.17833579
#  0.17613652 0.21538933 0.18922079 0.20817906 0.23415272 0.43481529]
# Predict this y:
#  [[0.13156649]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import GRU

import tensorflow as tf

# %%
# We're only using one feature in our time series
n_features = 1

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\Users\mandh\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 40901 (159.77 KB)
# Trainable params: 40901 (159.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\mandh\AppData\Local\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test, length=length, batch_size=1)

# %%
from tensorflow.keras.callbacks import EarlyStopping
EarlyStopping?
# Your code to create an object early-stop.

# %%
# Your code to fit your model.
early_stop = EarlyStopping(monitor='val_loss',patience=5)

# %%
# Get Losses from dataframe (hint - model.history.history)- See previous week tutorial.
# Plot losses in the dataframe.
history =  model.fit(generator,  epochs=30,
                    validation_data=validation_generator,
                    callbacks=[early_stop])
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\mandh\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 357/357 [==============================] - 4s 5ms/step - loss: 0.0196 - val_loss: 0.0868
# Epoch 2/30
# 357/357 [==============================] - 2s 4ms/step - loss: 0.0147 - val_loss: 0.0309
# Epoch 3/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0098 - val_loss: 0.0147
# Epoch 4/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0063 - val_loss: 0.0518
# Epoch 5/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0061 - val_loss: 0.0056
# Epoch 6/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 7/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0057 - val_loss: 0.0271
# Epoch 8/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 9/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 10/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 11/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 12/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0036 - val_loss: 0.0113
# Epoch 13/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 14/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0036 - val_loss: 9.5329e-04
# Epoch 15/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 16/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0031 - val_loss: 7.1342e-04
# Epoch 17/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0031 - val_loss: 8.7108e-04
# Epoch 18/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 19/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 20/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0031 - val_loss: 8.9768e-04
# Epoch 21/30
# 357/357 [==============================] - 1s 4ms/step - loss: 0.0025 - val_loss: 0.0027

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot();

# %%
# printing Loss for the neural network training process

history_dict = history.history
plt.style.use('seaborn-darkgrid')

acc_values = history_dict['loss']
val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'ro', label='Training loss')
plt.plot(epochs, val_acc_values, 'g', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()
# Out:
# C:\Users\mandh\AppData\Local\Temp\ipykernel_16560\2767392239.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
first_eval_batch = scaled_train[-length:]

# %%
n_input = 12
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))
model.predict(first_eval_batch)
# Out:
# 1/1 [==============================] - 0s 300ms/step
# array([[0.5836724]], dtype=float32)

# %%
# compare with the true result:
scaled_test[0]
# Out:
# array([0.59761699])

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

current_batch
# Out:
# array([[[0.59486094],
#         [0.71362156],
#         [1.        ],
#         [0.41557863],
#         [0.47983074],
#         [0.62133571],
#         [0.62492692],
#         [0.65087275],
#         [0.60026169],
#         [0.60560675],
#         [0.63681412],
#         [0.56724479]]])

# %%
for i in range(len(test)):
    
    print(i)
    
    # get prediction 1 time stamp ahead ([0] is for 
    # grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    print(current_pred)
    
    # store prediction
    test_predictions.append(current_pred) 
    print(test_predictions)
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
    print(current_batch)
# Out:
# 0
# 1/1 [==============================] - 0s 16ms/step
# [0.5836724]
# [array([0.5836724], dtype=float32)]
# [[[0.71362156]
#   [1.        ]
#   [0.41557863]
#   [0.47983074]
#   [0.62133571]
#   [0.62492692]
#   [0.65087275]
#   [0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]]]
# 1
# 1/1 [==============================] - 0s 18ms/step
# [0.6843721]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32)]
# [[[1.        ]
#   [0.41557863]
#   [0.47983074]
#   [0.62133571]
#   [0.62492692]
#   [0.65087275]
#   [0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]]]
# 2
# 1/1 [==============================] - 0s 25ms/step
# [0.9216948]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32)]
# [[[0.41557863]
#   [0.47983074]
#   [0.62133571]
#   [0.62492692]
#   [0.65087275]
#   [0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]]]
# 3
# 1/1 [==============================] - 0s 25ms/step
# [0.4522634]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32)]
# [[[0.47983074]
#   [0.62133571]
#   [0.62492692]
#   [0.65087275]
#   [0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]]]
# 4
# 1/1 [==============================] - 0s 19ms/step
# [0.49684864]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32)]
# [[[0.62133571]
#   [0.62492692]
#   [0.65087275]
#   [0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]]]
# 5
# 1/1 [==============================] - 0s 16ms/step
# [0.56623226]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32)]
# [[[0.62492692]
#   [0.65087275]
#   [0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]]]
# 6
# 1/1 [==============================] - 0s 30ms/step
# [0.5883133]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32)]
# [[[0.65087275]
#   [0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]]]
# 7
# 1/1 [==============================] - 0s 29ms/step
# [0.621182]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32)]
# [[[0.60026169]
#   [0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]]]
# 8
# 1/1 [==============================] - 0s 31ms/step
# [0.5942735]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32)]
# [[[0.60560675]
#   [0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]]]
# 9
# 1/1 [==============================] - 0s 29ms/step
# [0.59550625]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32)]
# [[[0.63681412]
#   [0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]]]
# 10
# 1/1 [==============================] - 0s 26ms/step
# [0.61838263]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32)]
# [[[0.56724479]
#   [0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]]]
# 11
# 1/1 [==============================] - 0s 25ms/step
# [0.57020426]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32), array([0.57020426], dtype=float32)]
# [[[0.5836724 ]
#   [0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]
#   [0.57020426]]]
# 12
# 1/1 [==============================] - 0s 26ms/step
# [0.57051545]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32), array([0.57020426], dtype=float32), array([0.57051545], dtype=float32)]
# [[[0.68437213]
#   [0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]
#   [0.57020426]
#   [0.57051545]]]
# 13
# 1/1 [==============================] - 0s 26ms/step
# [0.6480637]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32), array([0.57020426], dtype=float32), array([0.57051545], dtype=float32), array([0.6480637], dtype=float32)]
# [[[0.92169482]
#   [0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]
#   [0.57020426]
#   [0.57051545]
#   [0.64806372]]]
# 14
# 1/1 [==============================] - 0s 26ms/step
# [0.87047553]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32), array([0.57020426], dtype=float32), array([0.57051545], dtype=float32), array([0.6480637], dtype=float32), array([0.87047553], dtype=float32)]
# [[[0.45226341]
#   [0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]
#   [0.57020426]
#   [0.57051545]
#   [0.64806372]
#   [0.87047553]]]
# 15
# 1/1 [==============================] - 0s 33ms/step
# [0.46764433]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32), array([0.57020426], dtype=float32), array([0.57051545], dtype=float32), array([0.6480637], dtype=float32), array([0.87047553], dtype=float32), array([0.46764433], dtype=float32)]
# [[[0.49684864]
#   [0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]
#   [0.57020426]
#   [0.57051545]
#   [0.64806372]
#   [0.87047553]
#   [0.46764433]]]
# 16
# 1/1 [==============================] - 0s 31ms/step
# [0.5009147]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32), array([0.57020426], dtype=float32), array([0.57051545], dtype=float32), array([0.6480637], dtype=float32), array([0.87047553], dtype=float32), array([0.46764433], dtype=float32), array([0.5009147], dtype=float32)]
# [[[0.56623226]
#   [0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]
#   [0.57020426]
#   [0.57051545]
#   [0.64806372]
#   [0.87047553]
#   [0.46764433]
#   [0.50091469]]]
# 17
# 1/1 [==============================] - 0s 27ms/step
# [0.5379032]
# [array([0.5836724], dtype=float32), array([0.6843721], dtype=float32), array([0.9216948], dtype=float32), array([0.4522634], dtype=float32), array([0.49684864], dtype=float32), array([0.56623226], dtype=float32), array([0.5883133], dtype=float32), array([0.621182], dtype=float32), array([0.5942735], dtype=float32), array([0.59550625], dtype=float32), array([0.61838263], dtype=float32), array([0.57020426], dtype=float32), array([0.57051545], dtype=float32), array([0.6480637], dtype=float32), array([0.87047553], dtype=float32), array([0.46764433], dtype=float32), array([0.5009147], dtype=float32), array([0.5379032], dtype=float32)]
# [[[0.58831328]
#   [0.62118202]
#   [0.59427351]
#   [0.59550625]
#   [0.61838263]
#   [0.57020426]
#   [0.57051545]
#   [0.64806372]
#   [0.87047553]
#   [0.46764433]
#   [0.50091469]
#   [0.53790319]]]

# %%
scaler.inverse_transform?

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
# Print the test variable.
test
# Out:
#               sales
# DATE
# 2022-10-01  24243.0
# 2022-11-01  28045.0
# 2022-12-01  39263.0
# 2023-01-01  19118.0
# 2023-02-01  20666.0
# 2023-03-01  24510.0
# 2023-04-01  24232.0
# 2023-05-01  26096.0
# 2023-06-01  24364.0
# 2023-07-01  24911.0
# 2023-08-01  26657.0
# 2023-09-01  23332.0
# 2023-10-01  23933.0
# 2023-11-01  28580.0
# 2023-12-01  40684.0
# 2024-01-01  19188.0
# 2024-02-01  21964.0
# 2024-03-01  25293.0

# %%
# Your code to plot actual sales and predictions.
test.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
length = 12 # Length of the output sequences (in number of timesteps)
generator = TimeseriesGenerator(scaled_full_data, 
                                scaled_full_data, length=length, batch_size=1)

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))

# %%
# compile the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 100)               40800
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 40901 (159.77 KB)
# Trainable params: 40901 (159.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# use early_stop
model.compile(optimizer='adam', loss='mse')

# %%
# fit the model
early_stop = EarlyStopping(monitor='loss',patience=5)

# %%
history_2 =  model.fit(generator, epochs=30, callbacks=[early_stop])
# Out:
# Epoch 1/30
# 375/375 [==============================] - 4s 4ms/step - loss: 0.0198
# Epoch 2/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0136
# Epoch 3/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0108
# Epoch 4/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0066
# Epoch 5/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0063
# Epoch 6/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0045
# Epoch 7/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0042
# Epoch 8/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0039
# Epoch 9/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0040
# Epoch 10/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0036
# Epoch 11/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0037
# Epoch 12/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0037
# Epoch 13/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0032
# Epoch 14/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0027
# Epoch 15/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0031
# Epoch 16/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0029
# Epoch 17/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0026
# Epoch 18/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0028
# Epoch 19/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0025
# Epoch 20/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0024
# Epoch 21/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0023
# Epoch 22/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0023
# Epoch 23/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0023
# Epoch 24/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0024
# Epoch 25/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0021
# Epoch 26/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0020
# Epoch 27/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0018
# Epoch 28/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0018
# Epoch 29/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0019
# Epoch 30/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0019

# %%
history_dict = history_2.history
plt.style.use('seaborn-darkgrid')

acc_values = history_dict['loss']
#val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'bo', label='Training loss')
#plt.plot(epochs, val_acc_values, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()
# Out:
# C:\Users\mandh\AppData\Local\Temp\ipykernel_16560\117035865.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
forecast = []
# Replace periods with whatever forecast length you want
periods = 12

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for 
    # grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[23088.41630381],
#        [23461.75694698],
#        [22741.67188865],
#        [22567.5610159 ],
#        [23457.99082518],
#        [21826.38439083],
#        [21885.53969461],
#        [24990.16222322],
#        [33758.65940195],
#        [17216.68127668],
#        [19533.53132528],
#        [21303.59572715]])

# %%
df
# Out:
#               sales
# DATE
# 1992-01-01   6938.0
# 1992-02-01   7524.0
# 1992-03-01   8475.0
# 1992-04-01   9401.0
# 1992-05-01   9558.0
# ...             ...
# 2023-11-01  28580.0
# 2023-12-01  40684.0
# 2024-01-01  19188.0
# 2024-02-01  21964.0
# 2024-03-01  25293.0
#
# [387 rows x 1 columns]

# %%
forecast_index = pd.date_range(start='2024-01-01',periods=periods,freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast,index=forecast_index,
                           columns=['Forecast'])

# %%
forecast_df
# Out:
#                 Forecast
# 2024-01-01  23088.416304
# 2024-02-01  23461.756947
# 2024-03-01  22741.671889
# 2024-04-01  22567.561016
# 2024-05-01  23457.990825
# 2024-06-01  21826.384391
# 2024-07-01  21885.539695
# 2024-08-01  24990.162223
# 2024-09-01  33758.659402
# 2024-10-01  17216.681277
# 2024-11-01  19533.531325
# 2024-12-01  21303.595727

# %%
# Plot sales - Values in dataframe
df.plot();

# %%
# Plot forecast - Values in forecast_df
forecast_df.plot()
# Out:
# <Axes: >

# %%
ax = df.plot()
forecast_df.plot(ax=ax)
# Out:
# <Axes: xlabel='DATE'>

# %%
ax = df.plot()
forecast_df.plot(ax=ax)
plt.xlim('2022-01-01','2025-01-01')
# Out:
# (624.0, 660.0)
